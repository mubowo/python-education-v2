# %% [markdown]
# Username : Tunggul Sutrambuko Mubowo
# Assignment : Day 3 - Homework
#
# Details of assignment :
#
# User Login Application
#   * Get Username and Password values from the user
#   * Check the values in an if statement and tell the user if they were successful
#   * Try to building the same user login application but this time, use dictionay!

# %%
# Task #1
# Get Username and Password values from the user
# Check the values in an if statement and tell the user if they were successful

username = input("Enter your username: ")
password = input("Enter your password: ")

if (len(username) and len(password) == 0):
  print("Try again to login")
else:
  print("You have successfully to login")
# Out:
# Enter your username: joey
# Enter your password:
# Try again to login

# %%
# Task #2
# Try to building the same user login application, but this time, use dictionary!

username_pwd_dict = {
    "Joey":"Ranger12",
    "Mikhail":"#turboCar1!"
}

username = input("Enter your username : ")
password = input("Enter your password : ")

if (username in username_pwd_dict.keys() and password in username_pwd_dict.values()) :
  print("\nGreetings " + username + "! You have successfully login")
else:
  print("Sorry " + username + " You have to try it again. Thanks")
# Out:
# Enter your username : Joey
# Enter your password : Ranger12
# Joey
# Ranger12
#
# Greetings Joey! You have successfully login
